# %%
# %pip install opensoundscape
# Out:
# ...
#   Using cached opensoundscape-0.7.0-py3-none-any.whl (108 kB)
# ...
#   Using cached schema-0.7.5-py2.py3-none-any.whl (17 kB)
# ...
#   Using cached numba-0.55.2-cp38-cp38-macosx_10_14_x86_64.whl (2.3 MB)
# ...
#   Using cached tinytag-1.8.1-py3-none-any.whl
# ...
#   Using cached torchvision-0.12.0-cp38-cp38-macosx_10_9_x86_64.whl (1.3 MB)
# ...
#   Using cached scikit_image-0.19.2-cp38-cp38-macosx_10_13_x86_64.whl (13.1 MB)
# ...
#   Using cached Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# ...
#   Using cached librosa-0.9.1-py3-none-any.whl (213 kB)
# ...
#   Using cached ray-1.12.1-cp38-cp38-macosx_10_15_x86_64.whl (55.8 MB)
# ...
#   Using cached PyWavelets-1.3.0-cp38-cp38-macosx_10_13_x86_64.whl (4.3 MB)
# ...
#   Using cached torch-1.11.0-cp38-none-macosx_10_9_x86_64.whl (129.9 MB)
# ...
#   Using cached Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# ...
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# ...
#   Using cached scikit_learn-1.1.1-cp38-cp38-macosx_10_13_x86_64.whl (8.5 MB)
# ...
